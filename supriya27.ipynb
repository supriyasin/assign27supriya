# %%
#1. What is the result of the code, and explain?

>>>X = 'iNeuron'
>>>def func():
print(X)

>>>func()

""" 'iNeuron'
 The scope of variable X is for the whole file."""

#2. What is the result of the code, and explain?

>>>X = 'iNeuron'
>>>def func():
X = 'NI!'

>>>func()
>>>print(X)

""" 'NI!'
  The value of X is getting override inside the func block."""

#3. What does this code print, and why?

>>>X = 'iNeuron'
>>>def func():
X = 'NI'
print(X)

>>>func()
>>>print(X)

""" X 
    The return 'NI' type of code print. """

#4. What output does this code produce? Why?

>>>X = 'iNeuron'
>>>def func():
global X
X = 'NI'

>>>func()
>>>print(X)

""" 'NI'
    The value of X is getting override inside the func block."""

#5. What about this code—what’s the output, and why?

>>>X = 'iNeuron'
>>>def func():
X = 'NI'
def nested():
print(X)
nested()

>>>func()
>>>X

""" 'iNeuron' and 'NI'
  The output is X variable."""

#6. How about this code: what is its output in Python 3, and explain?

>>>def func():
X = 'NI'
def nested():
nonlocal X
X = 'Spam'
nested()
print(X)

>>>func()

""" 'Spam'
  The return value is X ."""
